# %%
# --- Imports ---
from config import CONFIG
from preprocessing import load_and_prepare
from training import run_training
from plotting import save_metrics, plot_confusion_matrix, plot_average_roc

print("Experiment settings:")
for k, v in CONFIG.items():
    if k != "split_files":
        print(f"{k}: {v}")
print(f"split_file: {CONFIG['split_files'][CONFIG['split_strategy']]}")
# Out:
# 2025-10-04 08:42:10.420644: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-04 08:42:11.314142: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Experiment settings:
# cell_line: NIHOVCAR3
# aggregation: mean
# normalization: dmso_zscore
# moa_condition: as_is
# split_strategy: structure
# batch_size: 16
# epochs: 1000
# learning_rate: 0.0001
# n_folds: 5
# k_features: 300
# data_root: ./Data_cp_features/
# metadata_file: {cell_line}_metadata.xlsx
# output_dir: ./results/
# split_file: Splitting_Smiles/structure_as_is_thr0.65_smiles.npz

# %%
# --- Preprocessing ---
print("Loading and preprocessing data...")
data_dict = load_and_prepare(CONFIG)
print("Preprocessing complete.")
# Out:
# Loading and preprocessing data...
# /home/gauss/Documents/Project 2: Combining Molecular and Imagining Data for MOA Prediction/smile_image_global/Global-based Model/preprocessing.py:78: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df.loc[:, ~df.columns.str.contains(r"(_X$|_Y$|_Z$)")]
# /home/gauss/Documents/Project 2: Combining Molecular and Imagining Data for MOA Prediction/smile_image_global/Global-based Model/preprocessing.py:78: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df.loc[:, ~df.columns.str.contains(r"(_X$|_Y$|_Z$)")]
# /home/gauss/Documents/Project 2: Combining Molecular and Imagining Data for MOA Prediction/smile_image_global/Global-based Model/preprocessing.py:78: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df.loc[:, ~df.columns.str.contains(r"(_X$|_Y$|_Z$)")]
# /home/gauss/Documents/Project 2: Combining Molecular and Imagining Data for MOA Prediction/smile_image_global/Global-based Model/preprocessing.py:78: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df.loc[:, ~df.columns.str.contains(r"(_X$|_Y$|_Z$)")]
# Preprocessing complete.

# %%
# --- Training ---
print("Training with cross-validation...")
results = run_training(CONFIG, data_dict)
print("Training complete.")
# Out:
# Training with cross-validation...
#
# === Fold 1/5 ===
# /home/gauss/miniconda3/envs/tf24/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-10-04 08:43:27.126424: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9612 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:17:00.0, compute capability: 7.5
# 2025-10-04 08:43:27.127898: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 8961 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759560210.016502  449331 service.cc:145] XLA service 0x748b0c0026a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759560210.016551  449331 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# I0000 00:00:1759560210.016560  449331 service.cc:153]   StreamExecutor device (1): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-10-04 08:43:30.101005: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-04 08:43:30.335128: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# I0000 00:00:1759560216.253012  449331 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved model for fold 1 → ./results/models/NIHOVCAR3_mean_dmso_zscore_structure_as_is_fold1.h5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# Test Accuracy=0.460, Precision=0.369, Recall=0.351, F1=0.349
#
# === Fold 2/5 ===
# /home/gauss/miniconda3/envs/tf24/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved model for fold 2 → ./results/models/NIHOVCAR3_mean_dmso_zscore_structure_as_is_fold2.h5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Test Accuracy=0.429, Precision=0.363, Recall=0.335, F1=0.324
#
# === Fold 3/5 ===
# /home/gauss/miniconda3/envs/tf24/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved model for fold 3 → ./results/models/NIHOVCAR3_mean_dmso_zscore_structure_as_is_fold3.h5
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x748ca87c2e80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x748ca87c2e80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Test Accuracy=0.519, Precision=0.448, Recall=0.448, F1=0.427
#
# === Fold 4/5 ===
# /home/gauss/miniconda3/envs/tf24/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved model for fold 4 → ./results/models/NIHOVCAR3_mean_dmso_zscore_structure_as_is_fold4.h5
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x748ca3f7f9c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x748ca3f7f9c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Test Accuracy=0.550, Precision=0.486, Recall=0.463, F1=0.458
#
# === Fold 5/5 ===
# /home/gauss/miniconda3/envs/tf24/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved model for fold 5 → ./results/models/NIHOVCAR3_mean_dmso_zscore_structure_as_is_fold5.h5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Test Accuracy=0.471, Precision=0.445, Recall=0.446, F1=0.424
#
# === Average across folds (Test Set) ===
# ACC: 0.486 ± 0.048
# PRECISION: 0.422 ± 0.054
# RECALL: 0.409 ± 0.060
# F1: 0.396 ± 0.057
#
# === Per-MOA average metrics (Test Set, across folds) ===
#                  precision  recall     f1
# moa
# AKT                  0.596   1.000  0.741
# AURORA KINASE        0.871   0.500  0.632
# CDK                  0.415   0.362  0.385
# EGFR                 0.727   0.630  0.670
# HDAC                 0.728   0.583  0.645
# HMGCR                0.153   0.200  0.167
# JAK                  0.193   0.173  0.177
# MTOR                 0.861   0.617  0.705
# PARP                 0.540   0.533  0.529
# TOPOISOMERASE        0.248   0.417  0.306
# TUBULIN              0.000   0.000  0.000
# TYROSINE KINASE      0.114   0.167  0.134
# VEGFR                0.042   0.133  0.064
# Training complete.

# %%
# --- Save metrics + plots ---
print("Step 3: Saving results...")
save_metrics(
    results["metrics_df"],results["mean_metrics"],results["std_metrics"],
    CONFIG,results["fold_reports"],results["int_to_label"])

plot_confusion_matrix(results["cumulative_cm"], results["int_to_label"], CONFIG)
plot_average_roc(results["y_true_folds"], results["y_prob_folds"], results["int_to_label"], CONFIG)
print("Results saved.")

print("Pipeline finished successfully!")
# Out:
# Step 3: Saving results...
# Saved fold metrics → ./results/NIHOVCAR3_mean_dmso_zscore_structure_as_is/fold_metrics.csv
# Saved summary metrics → ./results/NIHOVCAR3_mean_dmso_zscore_structure_as_is/summary_metrics.csv
# Saved per-MOA metrics → ./results/NIHOVCAR3_mean_dmso_zscore_structure_as_is/per_moa_metrics.csv
# Saved confusion matrix → ./results/NIHOVCAR3_mean_dmso_zscore_structure_as_is/confusion_matrix.png
# Saved ROC curves → ./results/NIHOVCAR3_mean_dmso_zscore_structure_as_is/roc_curves.png
# Results saved.
# Pipeline finished successfully!

# %% [markdown]
# ### Merge all the per metrics moa into 1 single csv file

# %%
import os
import pandas as pd

# Path to your results folder
base_path = "/home/gauss/Documents/Project 2: Combining Molecular and Imagining Data for MOA Prediction/Image model/Image-based model/results/"

# Define categories to group by
categories = [
    "as_is",
    "merge_tk_egfr_vegfr",
    "merge_tk_egfr_keep_vegfr",
    "merge_tk_vegfr_keep_egfr",
    "merge_all_kinases",
    "merge_st_vs_tk"
]

# Get all folders that start with "U2OS_"
folders = [f for f in os.listdir(base_path) if f.startswith("HEPG2_") and os.path.isdir(os.path.join(base_path, f))]

# Process each category separately
for category in categories:
    merged = None
    # Select only folders that contain the category keyword
    category_folders = [f for f in folders if category in f]
    
    for folder in category_folders:
        file_path = os.path.join(base_path, folder, "per_moa_metrics.csv")
        if os.path.exists(file_path):
            df = pd.read_csv(file_path)
            df = df.set_index("moa")
            df.columns = pd.MultiIndex.from_product([[folder], df.columns])  # folder name on top
            
            if merged is None:
                merged = df
            else:
                merged = merged.join(df, how="outer")
    
    # Save result for this category if we found any data
    if merged is not None:
        merged = merged.reset_index()
        output_path = os.path.join(base_path, f"HEPG2_merged_{category}.csv")
        merged.to_csv(output_path, index=False)
        print(f"Saved: {output_path}")
    else:
        print(f"No data found for category: {category}")
